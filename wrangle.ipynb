# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

import utils.helper as uh

# %%
data_dir = './data'

datafile = os.path.join(data_dir, 'DataAnalyst.csv')

df = pd.read_csv(datafile, index_col=0)

# %%
df
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Salary Estimate    2253 non-null   object
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 281.6+ KB

# %% [markdown]
# # Data Wrangling

# %%
df_cleaned = df.copy()

# %%
column_names_dict = {
    'Job Title': "job_title",
    'Salary Estimate': "salary_estimate",
    'Job Description': "job_description",
    'Rating': "rating",
    'Company Name': "company_name",
    'Location': "location",
    'Headquarters': "headquaters",
    'Size': "size",
    'Founded': "founded",
    'Type of ownership': "type_of_ownership",
    'Industry': "industry",
    'Sector': "sector",
    'Revenue': "revenue",
    'Competitors': "competitors",
    'Easy Apply': "easy_apply"
}

df_cleaned.rename(columns=column_names_dict, inplace=True)

# %%
df_cleaned.dropna(inplace=True)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2252 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          2252 non-null   object
#  1   salary_estimate    2252 non-null   object
#  2   job_description    2252 non-null   object
#  3   rating             2252 non-null   float64
#  4   company_name       2252 non-null   object
#  5   location           2252 non-null   object
#  6   headquaters        2252 non-null   object
#  7   size               2252 non-null   object
#  8   founded            2252 non-null   int64
#  9   type_of_ownership  2252 non-null   object
#  10  industry           2252 non-null   object
#  11  sector             2252 non-null   object
#  12  revenue            2252 non-null   object
#  13  competitors        2252 non-null   object
#  14  easy_apply         2252 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 281.5+ KB

# %%
df_cleaned['salary_estimate'] = df_cleaned['salary_estimate'].str.split('(').str[0].str.strip()

# %%
indice_to_remove = df_cleaned.query('salary_estimate == "-1"').index

df_cleaned.drop(indice_to_remove, inplace=True)

# %%
salary_counts = df_cleaned['salary_estimate'].value_counts()

# %%
indice_to_remove = df_cleaned.query('rating == "-1"').index

df_cleaned.drop(indice_to_remove, inplace=True)

# %% [markdown]
# # Data Visualization

# %%
current_palette = sns.color_palette("colorblind")

sns.set_palette(current_palette)

base_color=current_palette[0]

# %%
plt.rcParams['figure.figsize'] = (21, 21)

sns.countplot(y="salary_estimate", data=df_cleaned, color=base_color, order=salary_counts.index)

# %%
plt.rcParams['figure.figsize'] = (8, 8)

bins = np.arange(1, 5+0.5, 0.5)

plt.hist(df_cleaned['rating'], color=base_color, bins=bins)

plt.xticks(bins)

plt.show()

# %%
heatmap1_data = pd.pivot_table(df_cleaned, values='rating', 
                     index=['salary_estimate'])
                    

sns.heatmap(heatmap1_data, vmin=4, cmap="vlag")

plt.show()

# %% [markdown]
# # Predict salary based on industry, location, company revenue

# %%
df_new = df_cleaned.copy()

# %% [markdown]
# ## I. Data Wrangling

# %%
row_to_remove = df_new.query('industry == "-1"').index

df_new.drop(row_to_remove, inplace=True)

# %%
row_to_remove = df_new.query('revenue == "Unknown / Non-Applicable"').index

df_new.drop(row_to_remove, inplace=True)

# %%
df_new['revenue'].unique()
# Out:
# array(['$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        '$50 to $100 million (USD)', '$1 to $2 billion (USD)',
#        '$5 to $10 billion (USD)', '$1 to $5 million (USD)',
#        '$25 to $50 million (USD)', '$10+ billion (USD)',
#        'Less than $1 million (USD)', '$10 to $25 million (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 million (USD)'],
#       dtype=object)

# %%
df_new['revenue'] = df_new['revenue'].str.split('(').str[0].str.strip().str.replace('$', '')

# %%
df_new['revenue'].unique()
# Out:
# array(['100 to 500 million', '2 to 5 billion', '50 to 100 million',
#        '1 to 2 billion', '5 to 10 billion', '1 to 5 million',
#        '25 to 50 million', '10+ billion', 'Less than 1 million',
#        '10 to 25 million', '500 million to 1 billion', '5 to 10 million'],
#       dtype=object)

# %%
processed_revenue = df_new['revenue'].apply(uh.process_revenue)

# %%
df_new['min_revenue'], df_new['max_revenue'] = processed_revenue.str[0], processed_revenue.str[1]

# %%
df_new['salary_estimate'].unique()
# Out:
# array(['$37K-$66K', '$46K-$87K', '$51K-$88K', '$51K-$87K', '$59K-$85K',
#        '$43K-$76K', '$60K-$110K', '$41K-$78K', '$45K-$88K', '$73K-$127K',
#        '$84K-$90K', '$27K-$52K', '$42K-$74K', '$77K-$132K', '$98K-$114K',
#        '$48K-$96K', '$26K-$47K', '$31K-$59K', '$47K-$81K', '$43K-$69K',
#        '$49K-$112K', '$30K-$54K', '$55K-$103K', '$37K-$70K', '$57K-$103K',
#        '$35K-$45K', '$42K-$66K', '$65K-$81K', '$113K-$132K', '$60K-$66K',
#        '$73K-$82K', '$67K-$92K', '$42K-$76K', '$97K-$129K', '$68K-$87K',
#        '$29K-$38K', '$47K-$76K', '$74K-$123K', '$53K-$94K', '$46K-$102K',
#        '$43K-$94K', '$45K-$78K', '$38K-$68K', '$37K-$44K', '$64K-$113K',
#        '$50K-$93K', '$37K-$68K', '$73K-$89K', '$76K-$122K', '$60K-$124K',
#        '$34K-$61K', '$24K-$48K', '$30K-$53K', '$41K-$86K', '$44K-$82K',
#        '$48K-$88K', '$44K-$78K', '$110K-$190K', '$89K-$151K',
#        '$69K-$127K', '$51K-$93K', '$58K-$93K', '$63K-$116K', '$53K-$104K',
#        '$35K-$42K', '$43K-$77K', '$40K-$72K', '$50K-$86K', '$35K-$67K',
#        '$57K-$70K', '$28K-$52K', '$46K-$86K', '$54K-$75K', '$53K-$99K',
#        '$40K-$74K', '$57K-$104K', '$99K-$178K', '$93K-$159K',
#        '$82K-$116K', '$65K-$120K', '$47K-$74K', '$55K-$101K', '$32K-$56K',
#        '$36K-$67K', '$57K-$67K', '$49K-$91K', '$57K-$100K', '$78K-$104K'],
#       dtype=object)

# %%
salary_estimate = df_new['salary_estimate'].str.replace(r'[$|K]', '').str.split('-')

# %%
df_new['min_salary_estimate'], df_new['max_salary_estimate'] = \
    salary_estimate.str[0].astype(int) * 1000, salary_estimate.str[1].astype(int) * 1000

# %%
splitted_locations = df_new['location'].str.split(',')

df_new['city'], df_new['state'] = splitted_locations.str[0], splitted_locations.str[1]

# %%
df_new['avg_salary_estimate'] = sum([df_new['min_salary_estimate'], df_new['max_salary_estimate']]) / 2

df_new['avg_salary_estimate'] = pd.to_numeric(df_new['avg_salary_estimate'], downcast='integer')

# %%
df_new['avg_revenue'] = sum([df_new['min_revenue'], df_new['max_revenue']]) / 2

# %%
df_new
# Out:
#                                               job_title salary_estimate  \
# 0     Data Analyst, Center on Immigration and Justic...       $37K-$66K
# 1                                  Quality Data Analyst       $37K-$66K
# 3                                          Data Analyst       $37K-$66K
# 4                                Reporting Data Analyst       $37K-$66K
# 7                                  Data Science Analyst       $37K-$66K
# ...                                                 ...             ...
# 2245            Data Analyst Supporting the DEA #20-242      $78K-$104K
# 2247  Marketing/Communications - Data Analyst-Marketing      $78K-$104K
# 2249              Senior Data Analyst (Corporate Audit)      $78K-$104K
# 2251                Data Analyst 3, Customer Experience      $78K-$104K
# 2252                        Senior Quality Data Analyst      $78K-$104K
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# 7     Data Science Analyst\n\nJob Details\nLevel\nEx...     3.7
# ...                                                 ...     ...
# 2245  Salary:\nPublished Job Title:\nData Analyst Su...     2.8
# 2247  Job Description\nJob Title: Marketing/Communic...     4.1
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  company_name        location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# 7                GNY Insurance Companies\n3.7    New York, NY
# ...                                       ...             ...
# 2245       Forfeiture Support Associates\n2.8  Centennial, CO
# 2247          APN Software Services Inc.\n4.1  Broomfield, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#            headquaters                    size  founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# 7         New York, NY    201 to 500 employees     1914
# ...                ...                     ...      ...
# 2245       Ashburn, VA  1001 to 5000 employees     2004
# 2247        Newark, CA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    type_of_ownership  ...  \
# 0             Nonprofit Organization  ...
# 1             Nonprofit Organization  ...
# 3     Subsidiary or Business Segment  ...
# 4                  Company - Private  ...
# 7                  Company - Private  ...
# ...                              ...  ...
# 2245               Company - Private  ...
# 2247               Company - Private  ...
# 2249                Company - Public  ...
# 2251               Company - Private  ...
# 2252          Nonprofit Organization  ...
#
#                                             competitors easy_apply  \
# 0                                                    -1       True
# 1                                                    -1         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# 7                      Travelers, Chubb, Crum & Forster       True
# ...                                                 ...        ...
# 2245                                                 -1         -1
# 2247                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
#      min_revenue max_revenue min_salary_estimate  max_salary_estimate  \
# 0            100         500               37000                66000
# 1           2000        5000               37000                66000
# 3             50         100               37000                66000
# 4            100         500               37000                66000
# 7            100         500               37000                66000
# ...          ...         ...                 ...                  ...
# 2245          50         100               78000               104000
# 2247          25          50               78000               104000
# 2249       10000       10000               78000               104000
# 2251          25          50               78000               104000
# 2252        2000        5000               78000               104000
#
#             city  state  avg_salary_estimate avg_revenue
# 0       New York     NY                51500       300.0
# 1       New York     NY                51500      3500.0
# 3       New York     NY                51500        75.0
# 4       New York     NY                51500       300.0
# 7       New York     NY                51500       300.0
# ...          ...    ...                  ...         ...
# 2245  Centennial     CO                91000        75.0
# 2247  Broomfield     CO                91000        37.5
# 2249  Centennial     CO                91000     10000.0
# 2251  Centennial     CO                91000        37.5
# 2252  Broomfield     CO                91000      3500.0
#
# [1413 rows x 23 columns]

# %%
df_new.columns
# Out:
# Index(['job_title', 'salary_estimate', 'job_description', 'rating',
#        'company_name', 'location', 'headquaters', 'size', 'founded',
#        'type_of_ownership', 'industry', 'sector', 'revenue', 'competitors',
#        'easy_apply', 'min_revenue', 'max_revenue', 'min_salary_estimate',
#        'max_salary_estimate', 'city', 'state', 'avg_salary_estimate',
#        'avg_revenue'],
#       dtype='object')

# %%
df_final = df_new[[
    'industry', 
    'city',
    'state',
    'min_revenue', 
    'max_revenue', 
    'min_salary_estimate', 
    'max_salary_estimate',
    'avg_salary_estimate',
    'avg_revenue'
]]

# %%
df_final.reset_index().drop('index', axis=1, inplace=True)

# %%
df_final
# Out:
#                                      industry        city state  min_revenue  \
# 0                           Social Assistance    New York    NY          100
# 1            Health Care Services & Hospitals    New York    NY         2000
# 3                                 IT Services    New York    NY           50
# 4                         Sports & Recreation    New York    NY          100
# 7                          Insurance Carriers    New York    NY          100
# ...                                       ...         ...   ...          ...
# 2245                   Staffing & Outsourcing  Centennial    CO           50
# 2247             Computer Hardware & Software  Broomfield    CO           25
# 2249                                Wholesale  Centennial    CO        10000
# 2251  Enterprise Software & Network Solutions  Centennial    CO           25
# 2252         Health Care Services & Hospitals  Broomfield    CO         2000
#
#       max_revenue  min_salary_estimate  max_salary_estimate  \
# 0             500                37000                66000
# 1            5000                37000                66000
# 3             100                37000                66000
# 4             500                37000                66000
# 7             500                37000                66000
# ...           ...                  ...                  ...
# 2245          100                78000               104000
# 2247           50                78000               104000
# 2249        10000                78000               104000
# 2251           50                78000               104000
# 2252         5000                78000               104000
#
#       avg_salary_estimate  avg_revenue
# 0                   51500        300.0
# 1                   51500       3500.0
# 3                   51500         75.0
# 4                   51500        300.0
# 7                   51500        300.0
# ...                   ...          ...
# 2245                91000         75.0
# 2247                91000         37.5
# 2249                91000      10000.0
# 2251                91000         37.5
# 2252                91000       3500.0
#
# [1413 rows x 9 columns]

# %%
output_csv_filepath = os.path.join(data_dir, "processed_data.csv")

df_final.to_csv (output_csv_filepath, index = True, header = True)
